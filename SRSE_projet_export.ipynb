# %%
import pandas as pd

# %%
#Code that extracts the data we use from a much larger dataset that comes from here https://git.nomics.world/dbnomics-source-data/cepii-source-data/-/blob/master/TRADE/trade_chel_YYYYMMDD.csv
"""
trade=pd.read_csv('trade_data.csv', usecols=['exporter', 'importer', 'secgroup', 'product', 'v2020'], sep=';')
trade_undifferenciated=trade[trade['product']=='TT']
trade_undifferenciated=trade_undifferenciated[['exporter','importer','secgroup','product','v2020']]
trade_undifferenciated.to_csv('Data_exports.csv')
"""

# %%
data=pd.read_csv('Data_exports.csv', index_col=0)

# %%
data
# Out:
#       exporter importer secgroup product          v2020
# 0          AES      AES      CAT      TT  227476.045916
# 1          AES      AFA      CAT      TT    1437.590947
# 2          AES      AFN      CAT      TT    5408.519442
# 3          AES      AFR      CAT      TT   47568.935618
# 4          AES      AFS      CAT      TT   16271.739595
# ...        ...      ...      ...     ...            ...
# 19316      YUG      VEN      CAT      TT       1.633391
# 19317      YUG      VNM      CAT      TT     114.547872
# 19318      YUG      WLD      CAT      TT   85068.226420
# 19319      YUG      XXX      CAT      TT     132.854201
# 19320      YUG      YUG      CAT      TT   17194.157859
#
# [19321 rows x 5 columns]

# %%
dic['AES']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-3565eb3af253> in <module>
# ----> 1 dic['AES']
#
# KeyError: 'AES'

# %%
code_country= pd.read_csv('country_codes_3.csv', encoding='latin-1', sep=';')

# %%
code_country_reduced=code_country[['iso_3digit_alpha', 'country_name_full']]

# %%
dic = code_country_reduced.set_index('iso_3digit_alpha').T.to_dict('list')
# Out:
# <ipython-input-30-655fad0f3bcd>:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dic = code_country_reduced.set_index('iso_3digit_alpha').T.to_dict('list')

# %%
dic
# Out:
# {'AFG': ['Afghanistan'],
#  'ALB': ['Albania'],
#  'DZA': ['Algeria'],
#  'ASM': ['American Samoa'],
#  'AND': ['Andorra'],
#  'AGO': ['Angola'],
#  'ATA': ['Antigua and Barbuda'],
#  'AZE': ['Azerbaijan'],
#  'ARG': ['Argentina'],
#  'AUS': ['Australia'],
#  'AUT': ['Austria'],
#  'BHS': ['Bahamas'],
#  'BHR': ['Bahrain'],
#  'BGD': ['Bangladesh'],
#  'ARM': ['Armenia'],
#  'BRB': ['Barbados'],
#  'BEL': ['Belgium-Luxembourg'],
#  'BMU': ['Bermuda'],
#  'BTN': ['Bhutan'],
#  'BOL': ['Plurinational State of Bolivia'],
#  'BIH': ['Bosnia Herzegovina'],
#  'BRA': ['Brazil'],
#  'BLZ': ['Belize'],
#  'IOT': ['British Indian Ocean Territories'],
#  'SLB': ['Solomon Islands'],
#  'VGB': ['British Virgin Islands'],
#  'BRN': ['Brunei Darussalam'],
#  'BGR': ['Bulgaria'],
#  'MMR': ['Myanmar'],
#  'BDI': ['Burundi'],
#  'BLR': ['Belarus'],
#  'KHM': ['Cambodia'],
#  'CMR': ['Cameroon'],
#  'CAN': ['Canada'],
#  'CPV': ['Cabo Verde'],
#  'CYM': ['Cayman Islands'],
#  'CAF': ['Central African Republic'],
#  'LKA': ['Sri Lanka'],
#  'TCD': ['Chad'],
#  'CHL': ['Chile'],
#  'CHN': ['China'],
#  'CXR': ['Christmas Islands'],
#  'CCK': ['Cocos Islands'],
#  'COL': ['Colombia'],
#  'COM': ['Comoros'],
#  'COG': ['Congo'],
#  'COD': ['Democratic Republic of the Congo'],
#  'COK': ['Cook Islands'],
#  'CRI': ['Costa Rica'],
#  'HRV': ['Croatia'],
#  'CUB': ['Cuba'],
#  'CYP': ['Cyprus'],
#  'CSK': ['Czechoslovakia'],
#  'CZE': ['Czechia'],
#  'BEN': ['Benin'],
#  'DNK': ['Denmark'],
#  'DMA': ['Dominica'],
#  'DOM': ['Dominican Republic'],
#  'ECU': ['Ecuador'],
#  'SLV': ['El Salvador'],
#  'GNQ': ['Equatorial Guinea'],
#  'ETH': ['Ethiopia'],
#  'ERI': ['Eritrea'],
#  'EST': ['Estonia'],
#  'FLK': ['Falkland Islands (Malvinas)'],
#  'FJI': ['Fiji'],
#  'FIN': ['Finland'],
#  'FRA': ['France et Monaco'],
#  'PYF': ['French Polynesia'],
#  'ATF': ['French South Antarctic Territories'],
#  'DJI': ['Djibouti'],
#  'GAB': ['Gabon'],
#  'GEO': ['Georgia'],
#  'GMB': ['Gambia'],
#  'PSE': ['State of Palestine'],
#  'DEU': ['Germany'],
#  'GHA': ['Ghana'],
#  'GIB': ['Gibraltar'],
#  'KIR': ['Kiribati'],
#  'GRC': ['Greece'],
#  'GRL': ['Greenland'],
#  'GRD': ['Grenada'],
#  'GUM': ['Guam'],
#  'GTM': ['Guatemala'],
#  'GIN': ['Guinea'],
#  'GUY': ['Guyana'],
#  'HTI': ['Haiti'],
#  'HND': ['Honduras'],
#  'HKG': ['China and Hong Kong Special Administrative Region'],
#  'HUN': ['Hungary'],
#  'ISL': ['Iceland'],
#  'IDN': ['Indonesia'],
#  'IRN': ['Iran'],
#  'IRQ': ['Iraq'],
#  'IRL': ['Ireland'],
#  'ISR': ['Israel'],
#  'ITA': ['Italy'],
#  'CIV': ["Côte d'Ivoire"],
#  'JAM': ['Jamaica'],
#  'JPN': ['Japan'],
#  'KAZ': ['Kazakhstan'],
#  'JOR': ['Jordan'],
#  'KEN': ['Kenya'],
#  'PRK': ["Democratic People's Republic of Korea"],
#  'KOR': ['Republic of Korea'],
#  'KWT': ['Kuwait'],
#  'KGZ': ['Kyrgyzstan'],
#  'LAO': ["Lao People's Dem. Rep."],
#  'LBN': ['Lebanon'],
#  'LVA': ['Latvia'],
#  'LBR': ['Liberia'],
#  'LBY': ['Libya'],
#  'LTU': ['Lithuania'],
#  'MAC': ['China- Macao Special Administrative Region'],
#  'MDG': ['Madagascar'],
#  'MWI': ['Malawi'],
#  'MYS': ['Malaysia'],
#  'MDV': ['Maldives'],
#  'MLI': ['Mali'],
#  'MLT': ['Malta'],
#  'MRT': ['Mauritania'],
#  'MUS': ['Mauritius'],
#  'MEX': ['Mexico'],
#  nan: ['Europe EFTA- not elsewhere specified'],
#  'MNG': ['Mongolia'],
#  'MDA': ['Republic of Moldova'],
#  'MNE': ['Montenegro'],
#  'MSR': ['Montserrat'],
#  'MAR': ['Morocco'],
#  'MOZ': ['Mozambique'],
#  'OMN': ['Oman'],
#  'NRU': ['Nauru'],
#  'NPL': ['Nepal'],
#  'NLD': ['Netherlands'],
#  'ANT': ['Netherlands Antilles'],
#  'CUW': ['Curaçao'],
#  'ABW': ['Aruba'],
#  'SXM': ['Saint Maarten (Dutch part)'],
#  'BES': ['Bonaire- Saint Eustatius and Saba'],
#  'NCL': ['New Caledonia'],
#  'VUT': ['Vanuatu'],
#  'NZL': ['New Zealand'],
#  'NIC': ['Nicaragua'],
#  'NER': ['Niger'],
#  'NGA': ['Nigeria'],
#  'NIU': ['Niue'],
#  'NFK': ['Norfolk Islands'],
#  'NOR': ['Norway- Svalbard and Jan Mayen'],
#  'MNP': ['Northern Mariana Islands'],
#  'FSM': ['Federated State of Micronesia'],
#  'MHL': ['Marshall Islands'],
#  'PLW': ['Palau'],
#  'PAK': ['Pakistan'],
#  'PAN': ['Panama'],
#  'PNG': ['Papua New Guinea'],
#  'PRY': ['Paraguay'],
#  'PER': ['Peru'],
#  'PHL': ['Philippines'],
#  'PCN': ['Pitcairn'],
#  'POL': ['Poland'],
#  'PRT': ['Portugal'],
#  'GNB': ['Guinea-Bissau'],
#  'TLS': ['Timor-Leste'],
#  'QAT': ['Qatar'],
#  'ROU': ['Romania'],
#  'RUS': ['Russian Federation'],
#  'RWA': ['Rwanda'],
#  'BLM': ['Saint Barthélemy'],
#  'SHN': ['Saint Helena'],
#  'KNA': ['Saint Kitts and Nevis'],
#  'AIA': ['Anguilla'],
#  'LCA': ['Saint Lucia'],
#  'SPM': ['Saint Pierre and Miquelon'],
#  'VCT': ['Saint Vincent and the Grenadines'],
#  'SMR': ['San Marino'],
#  'STP': ['Sao Tome and Principe'],
#  'SAU': ['Saudi Arabia'],
#  'SEN': ['Senegal'],
#  'SRB': ['Serbia'],
#  'SYC': ['Seychelles'],
#  'SLE': ['Sierra Leone'],
#  'IND': ['India'],
#  'SGP': ['Singapore'],
#  'SVK': ['Slovakia'],
#  'VNM': ['Viet Nam'],
#  'SVN': ['Slovenia'],
#  'SOM': ['Somalia'],
#  'ZAF': ['Southern African Customs Union'],
#  'ZWE': ['Zimbabwe'],
#  'ESP': ['Spain'],
#  'SSD': ['South Sudan'],
#  'SDN': ['Former Sudan'],
#  'SUR': ['Suriname'],
#  'SWE': ['Sweden'],
#  'CHE': ['Switzerland- Liechtenstein'],
#  'SYR': ['Syria'],
#  'TJK': ['Tajikistan'],
#  'THA': ['Thailand'],
#  'TGO': ['Togo'],
#  'TKL': ['Tokelau'],
#  'TON': ['Tonga'],
#  'TTO': ['Trinidad and Tobago'],
#  'ARE': ['United Arab Emirates'],
#  'TUN': ['Tunisia'],
#  'TUR': ['Turkey'],
#  'TKM': ['Turkmenistan'],
#  'TCA': ['Turks and Caicos Islands'],
#  'TUV': ['Tuvalu'],
#  'UGA': ['Uganda'],
#  'UKR': ['Ukraine'],
#  'MKD': ['The Former Yugoslav Republic of Macedonia'],
#  'SUN': ['Former USSR'],
#  'EGY': ['Egypt'],
#  'GBR': ['United Kingdom'],
#  'TZA': ['United Republic of Tanzania'],
#  'USA': ['USA- Puerto Rico and US Virgin Islands'],
#  'BFA': ['Burkina Faso'],
#  'URY': ['Uruguay'],
#  'UZB': ['Uzbekistan'],
#  'VEN': ['Venezuela'],
#  'WLF': ['Wallis and Futuna Islands'],
#  'WSM': ['Samoa'],
#  'YEM': ['Yemen'],
#  'SCG': ['Serbia and Montenegro'],
#  'ZMB': ['Zambia']}

# %%
dic.keys()
# Out:
# dict_keys(['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'ATA', 'AZE', 'ARG', 'AUS', 'AUT', 'BHS', 'BHR', 'BGD', 'ARM', 'BRB', 'BEL', 'BMU', 'BTN', 'BOL', 'BIH', 'BRA', 'BLZ', 'IOT', 'SLB', 'VGB', 'BRN', 'BGR', 'MMR', 'BDI', 'BLR', 'KHM', 'CMR', 'CAN', 'CPV', 'CYM', 'CAF', 'LKA', 'TCD', 'CHL', 'CHN', 'CXR', 'CCK', 'COL', 'COM', 'COG', 'COD', 'COK', 'CRI', 'HRV', 'CUB', 'CYP', 'CSK', 'CZE', 'BEN', 'DNK', 'DMA', 'DOM', 'ECU', 'SLV', 'GNQ', 'ETH', 'ERI', 'EST', 'FLK', 'FJI', 'FIN', 'FRA', 'PYF', 'ATF', 'DJI', 'GAB', 'GEO', 'GMB', 'PSE', 'DEU', 'GHA', 'GIB', 'KIR', 'GRC', 'GRL', 'GRD', 'GUM', 'GTM', 'GIN', 'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IDN', 'IRN', 'IRQ', 'IRL', 'ISR', 'ITA', 'CIV', 'JAM', 'JPN', 'KAZ', 'JOR', 'KEN', 'PRK', 'KOR', 'KWT', 'KGZ', 'LAO', 'LBN', 'LVA', 'LBR', 'LBY', 'LTU', 'MAC', 'MDG', 'MWI', 'MYS', 'MDV', 'MLI', 'MLT', 'MRT', 'MUS', 'MEX', nan, 'MNG', 'MDA', 'MNE', 'MSR', 'MAR', 'MOZ', 'OMN', 'NRU', 'NPL', 'NLD', 'ANT', 'CUW', 'ABW', 'SXM', 'BES', 'NCL', 'VUT', 'NZL', 'NIC', 'NER', 'NGA', 'NIU', 'NFK', 'NOR', 'MNP', 'FSM', 'MHL', 'PLW', 'PAK', 'PAN', 'PNG', 'PRY', 'PER', 'PHL', 'PCN', 'POL', 'PRT', 'GNB', 'TLS', 'QAT', 'ROU', 'RUS', 'RWA', 'BLM', 'SHN', 'KNA', 'AIA', 'LCA', 'SPM', 'VCT', 'SMR', 'STP', 'SAU', 'SEN', 'SRB', 'SYC', 'SLE', 'IND', 'SGP', 'SVK', 'VNM', 'SVN', 'SOM', 'ZAF', 'ZWE', 'ESP', 'SSD', 'SDN', 'SUR', 'SWE', 'CHE', 'SYR', 'TJK', 'THA', 'TGO', 'TKL', 'TON', 'TTO', 'ARE', 'TUN', 'TUR', 'TKM', 'TCA', 'TUV', 'UGA', 'UKR', 'MKD', 'SUN', 'EGY', 'GBR', 'TZA', 'USA', 'BFA', 'URY', 'UZB', 'VEN', 'WLF', 'WSM', 'YEM', 'SCG', 'ZMB'])

# %%
def complete_name (x):
    if x in dic.keys() :
        return dic[x][0]
    else :
        return ''
data['exporter_name']=data['exporter'].apply(complete_name)
data['importer_name']=data['importer'].apply(complete_name)

# %%
data
# Out:
#       exporter importer secgroup product          v2020 exporter_name  \
# 0          AES      AES      CAT      TT  227476.045916
# 1          AES      AFA      CAT      TT    1437.590947
# 2          AES      AFN      CAT      TT    5408.519442
# 3          AES      AFR      CAT      TT   47568.935618
# 4          AES      AFS      CAT      TT   16271.739595
# ...        ...      ...      ...     ...            ...           ...
# 19316      YUG      VEN      CAT      TT       1.633391
# 19317      YUG      VNM      CAT      TT     114.547872
# 19318      YUG      WLD      CAT      TT   85068.226420
# 19319      YUG      XXX      CAT      TT     132.854201
# 19320      YUG      YUG      CAT      TT   17194.157859
#
#       importer_name
# 0
# 1
# 2
# 3
# 4
# ...             ...
# 19316     Venezuela
# 19317      Viet Nam
# 19318
# 19319
# 19320
#
# [19321 rows x 7 columns]
